# %%
def greet():
    print("Hello World")

greet()

# def welcome_user():
#     print("Welcome to 4Achievers!")
def welcome_user(Name):
    print(f"Hello  {Name} , Welcome to 4Achievers!")

welcome_user("Aman")

def add_number(a,b):
    return a * b

print(add_number(12,67))
# Out:
# Hello World
# Hello  Aman , Welcome to 4Achievers!
# 804

# %% [markdown]
# Task 1: The Area Calculator
# Goal: Create a function that calculates the area of a rectangle.
#
# Function Name: calculate_area(length, width)
#
# Input: Take two numbers as arguments.
#
# Logic: Multiply length and width.
#
# Output: The function should return the result.
#
# Bonus: Call the function and print: "The area of the rectangle is: [result]".
#
# Task 2: List Filter (The "Junior Developer" Finder)
# Goal: You have a list of experience years, and you need to find who is a "Senior".
#
# Data: years_of_exp = [2, 5, 8, 1, 12, 4, 7]
#
# Task: Create a new list called senior_devs that only contains years greater than 5.
#
# Method: Use a for loop and an if statement.
#
# Output: Print the senior_devs list.
#
# Task 3: The Username Generator
# Goal: Create a function that formats a name for an Instagram handle (like your webgyaan.hub).
#
# Function Name: generate_handle(name)
#
# Input: A string (e.g., "Ganesh Dutt").
#
# Logic: 1. Convert the name to lowercase.
# 2. Replace the space with an underscore _.
# 3. Add @ at the beginning.
#
# Output: Return the new handle (e.g., @ganesh_dutt).
#
# Task 4: Dictionary Search (Database Simulation)
# Goal: Simulate a student database search.
#
# Data: Create a dictionary called student_scores with 3-4 names as keys and their marks as values.
#
# Task: Take a name as input from the user.
#
# Logic: Check if the name exists in the dictionary.
#
# If yes: Print "Score of [name] is [marks]".
#
# If no: Print "Student not found in 4Achievers database".

# %%
def generate_handle(name):
    # return f"@{name.lower().replace(' ','_')}"

     lower_name = name.lower()
     nameF = lower_name.replace(" ", "_")
     newUserName = f"@{nameF}"
     return newUserName

print(generate_handle("Ganesh Dutt"))
# Out:
# @ganesh_dutt

# %%
years_of_exp = [2, 5, 8, 1, 12, 4, 7]
senior_devs =[]
for year in years_of_exp:
    if year > 5:
        senior_devs.append(year)
print(senior_devs)
# Out:
# [8, 12, 7]
