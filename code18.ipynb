# %%
students = {
   "std1": {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
},
"std2": {
    "name":"manmohan",
    "age":3,
    "is_active":True,
    "city":"Delhi"
},
"std3": {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}
}

# for i in students:
#  name  =  students[i]["name"]
#  age  =   students[i]["age"]
#  print(name , ":", age)
 # print(student["age"])

# print(students["std1"])
# print(students["std2"])
# print(students["std3"])
# Out:
# manmohan : 23
# manmohan : 3
# manmohan : 23

# %% [markdown]
# dic = {
#     "key":"value"
# }
