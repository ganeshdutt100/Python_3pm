# %%
# for i in range(1, 16, 2):
#     print(i)

# fruits = ["Apple", "Banana", "Cherry", "Date", "Elderberry", "Fig", "Grape", "Honeydew", "Iceberg", "Jackfruit"]  

# for x in fruits:
#     print(x)

# %%
# i = 2 
# while i <= 5:
#    print(i)
#    i +=2

# %%
# for i in range(10,20+1):
#     if i % 2 == 0:
#         print(i)

# n = int(input("Enter your number :  "))
# sum = 0
# for i in range(1,n+1):
#     sum += i
# print(sum)

# num  = int(input("Enter your number :  "))

# for  i in range(1,11):
#     print(num, "*", i, "=", num * i)
# 2 * 1 = 2

# num = int(input("Enter your number :  "))
# print( type(num), num)


# num = 5
# for i in range(1,num+1):
#     print(i* "*")


n = 5
fact =1
for i in range(1,n+1):
    fact *= i
print(fact)
# Out:
# 120

# %%
# # input 1234
# # output 4321

# num = 1234
# rev = 0

for i in range(len(str(num))):
    digit = num%10
    rev = rev*10+digit
    num //= 10
print(rev)   

# first Round 
# #digit = 1234 % 10 =  4   
# #rev = 0 *10 +4  = 4
# #num = 1234 // 10 = 123

# second Round 
# #digit = 123 % 10 =  3
# #rev = 4 *10 +3  = 43
# #num = 123 // 10 = 12

# third Round 
# #digit = 12 % 10 =  2
# #rev = 43 *10 +2  = 432
# #num = 12 // 10 = 1

# 4th Round 
# #digit = 1 % 10 =  .1
# #rev = 432 *10 +1  = 4321
# #num = 1 // 10 = 0
# Out:
# 4321

# %%
text  =  "akshay"
count  =  0
for i in text:
    if i in "aeiou":
        count += 1
print("Vowels in the text : ", count)
# Out:
# Vowels in the text :  2
