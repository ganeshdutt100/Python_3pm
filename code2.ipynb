# %%
def student_profile(name,*skills , **details):
    print(f"Student Name: {name} ,  skills {skills} , details {details}")

student_profile("Akshay" ,  "Python" , "React" ,  "Node" , city="Mumbai" , state="Maharashtra" , country="India" , pincode=400001)
# Out:
# Student Name: Akshay ,  skills ('Python', 'React', 'Node') , details {'city': 'Mumbai', 'state': 'Maharashtra', 'country': 'India', 'pincode': 400001}

# %%
# lambda arguments : expression 
def add(a,b): return a+b
print(add(1,2))


add_lambda  = lambda a,b : a+b
print(add_lambda(1,2))
# Out:
# 3
# 3

# %%
# # math 
# random 
# datetime

import math 
import random
from datetime import datetime

print(math.sqrt(12))
print(random.randint(1,10))
print(datetime.now())
# Out:
# 3.4641016151377544
# 2
# 2026-04-13 17:01:42.969157

# %%
import  helper
helper.message("Akshay")
# Out:
# Hello Akshay, welcome to 4Achievers!

# %%
trainer = "Ganesh Dutt"
def my_class():
    topic  = "python"
    print(f"{trainer} is teaching {topic}")

my_class() 
print(trainer)   
# print(topic)
# Out:
# Ganesh Dutt is teaching python
# Ganesh Dutt
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 8
#       6 my_class()
#       7 print(trainer)
# ----> 8 print(topic)
#
# NameError: name 'topic' is not defined
