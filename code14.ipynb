# %%
# fruits = ["apple", "banana", "orange"]
# fruits.remove("orange") 
# fruit_remove=  fruits.pop(2)
# print(fruit_remove)
# fruits[1]="Python"
# print(fruits)
# print(fruits)
# print(fruits[0])
# print(fruits[1])
# print(fruits[2])
num = [40,50,80,10,40,70,90,60,100]
# print(num[2:7])
# print(num[:5])
# print(num[5:])
# print(num[::2])
# print(num[::-1])
# num.sort()
# print(num.count(40))

# print(num.index(60))
# print(num[-1])
# print(num[0:6])
# Out:
# 2
# 4
