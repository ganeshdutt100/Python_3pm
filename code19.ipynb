# %%
f  = open('students.txt','w')
f.write("Hello \n")
f.write("world")
f.close()

# %%
f  = open('students.txt','r')
content = f.read()
print(content)
f.close()
# Out:
# Hello
# world

# %%
with open("students.txt","r") as f:
    content = f.read()
    print(content)
# Out:
# Hello
# world
