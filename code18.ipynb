# %%
student = {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}
# print(student["age"])

for i in student:
    print(i  , ": " , student[i])
# Out:
# name :  manmohan
# age :  23
# is_active :  True
# city :  Delhi

# %% [markdown]
# dic = {
#     "key":"value"
# }
