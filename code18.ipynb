# %%
students = {
   "std1": {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
},
"std2": {
    "name":"manmohan",
    "age":3,
    "is_active":True,
    "city":"Delhi"
},
"std3": {
    "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}
}

# for i in students:
#  name  =  students[i]["name"]
#  age  =   students[i]["age"]
#  print(name , ":", age)
 # print(student["age"])

# print(students["std1"])
# print(students["std2"])
# print(students["std3"])
# Out:
# manmohan : 23
# manmohan : 3
# manmohan : 23

# %%
std={
     "name":"manmohan",
    "age":23,
    "is_active":True,
    "city":"Delhi"
}

print(std.keys())
print(std.values())
print(std.items())
print(std.get("name"))
std.update({"name":"aman"})
print(std)
# Out:
# dict_keys(['name', 'age', 'is_active', 'city'])
# dict_values(['manmohan', 23, True, 'Delhi'])
# dict_items([('name', 'manmohan'), ('age', 23), ('is_active', True), ('city', 'Delhi')])
# manmohan
# {'name': 'aman', 'age': 23, 'is_active': True, 'city': 'Delhi'}

# %% [markdown]
# dic = {
#     "key":"value"
# }
