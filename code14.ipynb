# %%
fruits = ["apple", "banana", "orange"]
fruits[1]="Python"
print(fruits)
# print(fruits)
# print(fruits[0])
# print(fruits[1])
# print(fruits[2])
# num = [1,2,3,4,5,6,7,6,54,3,45,67,8,76,543,2]
# print(num[-1])
# print(num[0:6])
# Out:
# ['apple', 'Python', 'orange']
